# %%
from pykrx import stock

ticker_lst = stock.get_market_ticker_list(date='20240813', market='KOSPI')
# print(ticker_lst)

for idx, ticker in enumerate(ticker_lst):
    ticker_name = stock.get_market_ticker_name(ticker)
    print(ticker_name)
    if idx >= 4:
        break
# Out:
# AJ네트웍스
# AK홀딩스
# BGF
# BGF리테일
# BNK금융지주

# %%
rslt_ohlcv_df = stock.get_market_ohlcv("20230621")
print(rslt_ohlcv_df)
# Out:
#             시가      고가      저가      종가       거래량         거래대금        등락률
# 티커
# 095570    4545    4655    4530    4550    107668    494560095   0.110000
# 006840   19990   19990   18500   19110     12208    235640040  -2.900000
# 027410    3995    3995    3885    3925     81090    318083585  -1.130000
# 282330  187900  187900  183000  183900     37726   6941433800  -1.660000
# 138930    6910    6930    6830    6890    638232   4394297500  -0.290000
# ...        ...     ...     ...     ...       ...          ...        ...
# 005010    6290    6290    6120    6150    609265   3756065910  -2.230000
# 000540    3170    3170    3135    3155     73918    232574735  -0.470000
# 000547    7600    9760    7350    9760     20596    178792560  29.959999
# 000545    5720    5920    5560    5910     15430     90931270   4.230000
# 003280    2050    2370    2025    2115  38871315  86208575410  12.140000
#
# [953 rows x 7 columns]

# %%
rslt_fund_df = stock.get_market_fundamental("20230621")
print(rslt_fund_df)
# Out:
#           BPS    PER   PBR    EPS   DIV   DPS
# 티커
# 095570   8076  22.64  0.56    201  5.93   270
# 006840  41948   0.00  0.46      0  1.05   200
# 027410  16528  15.89  0.24    247  2.80   110
# 282330  55724  16.42  3.30  11203  2.23  4100
# 138930  30468   2.87  0.23   2404  9.07   625
# ...       ...    ...   ...    ...   ...   ...
# 005010  16181   1.08  0.38   5675  5.69   350
# 000540  11208   1.47  0.28   2142  0.00     0
# 000547      0   0.00  0.00      0  0.00     0
# 000545      0   0.00  0.00      0  0.00     0
# 003280    544  22.50  3.89     94  0.00     0
#
# [923 rows x 6 columns]

# %%
rslt_tot_df = rslt_ohlcv_df.join(rslt_fund_df, how='inner')
print(rslt_tot_df)
# Out:
#             시가      고가      저가      종가       거래량         거래대금        등락률  \
# 티커
# 095570    4545    4655    4530    4550    107668    494560095   0.110000
# 006840   19990   19990   18500   19110     12208    235640040  -2.900000
# 027410    3995    3995    3885    3925     81090    318083585  -1.130000
# 282330  187900  187900  183000  183900     37726   6941433800  -1.660000
# 138930    6910    6930    6830    6890    638232   4394297500  -0.290000
# ...        ...     ...     ...     ...       ...          ...        ...
# 005010    6290    6290    6120    6150    609265   3756065910  -2.230000
# 000540    3170    3170    3135    3155     73918    232574735  -0.470000
# 000547    7600    9760    7350    9760     20596    178792560  29.959999
# 000545    5720    5920    5560    5910     15430     90931270   4.230000
# 003280    2050    2370    2025    2115  38871315  86208575410  12.140000
#
#           BPS    PER   PBR    EPS   DIV   DPS
# 티커
# ...

# %%
rslt_tot_df = rslt_tot_df.sort_values(by=['등락률'],ascending=False)
rslt_tot_df.reset_index(inplace=True)
print(rslt_tot_df)
# Out:
#          티커      시가      고가      저가      종가      거래량          거래대금        등락률  \
# 0    001745   28750   37700   26350   37700    21273     713352150  30.000000
# 1    000547    7600    9760    7350    9760    20596     178792560  29.959999
# 2    100220    5400    6990    5340    6820  7809842   50951798670  26.770000
# 3    000480   11800   14570   11530   13620  8362129  115717694520  21.500000
# 4    004565   29550   37500   28900   35150     7763     263075500  18.950001
# ..      ...     ...     ...     ...     ...      ...           ...        ...
# 918  241560   55100   56000   54200   55000  7464321  412071952800  -8.180000
# 919  460850   14460   14880   13170   13180  1025586   14081455970  -8.730000
# 920  457190  403500  415000  351000  357500   890953  333077172500 -11.290000
# 921  079160   11550   12450   11370   11440  2842618   33924919870 -21.100000
# 922  008110    6800    6960    6170    6430   463628    3015064040 -23.629999
#
# ...

# %%
for idx, row in rslt_tot_df.iterrows():
    ticker_name = stock.get_market_ticker_name(row['티커'])
    fluc_rate = row['등락률']
    open_value = row['시가']
    high_value = row['고가']
    low_value = row['저가']
    end_value = row['종가']
    volume = row['거래량']
    bps = row['BPS']
    per = row['PER']
    pbr = row['PBR']
    eps = row['EPS']
    div = row['DIV']
    dps = row['DPS']
    chatgpt_prompt = f'''
    오늘 KOSPI에서 {round(fluc_rate, 2)}%로 상승으로 마감한 {ticker_name}에 대한 정보야.
    {ticker_name}에 대한 회사 소개를 리포트로 만들어줘.
    그리고 아래 정보들도 포함해서 리포트로 만들어줘.
    등락률: {round(fluc_rate, 2)}
    시가: {open_value}
    고가: {high_value}
    저가: {low_value}
    종가: {end_value}
    거래량: {volume}
    BPS: {bps}
    PER: {per}
    PBR: {pbr}
    EPS: {eps}
    DIV: {div}
    DPS: {dps}
    '''

    print(chatgpt_prompt)
    if idx >=4:
        break
# Out:
#     오늘 KOSPI에서 30.0%로 상승으로 마감한 SK네트웍스우에 대한 정보야.
#     SK네트웍스우에 대한 회사 소개를 리포트로 만들어줘.
#     그리고 아래 정보들도 포함해서 리포트로 만들어줘.
#     등락률: 30.0
#     시가: 28750
#     고가: 37700
#     저가: 26350
#     종가: 37700
#     거래량: 21273
#     BPS: 0
#     PER: 0.0
#     PBR: 0.0
#     EPS: 0
#     DIV: 0.38
#     DPS: 145
#
#
#     오늘 KOSPI에서 29.96%로 상승으로 마감한 흥국화재2우B에 대한 정보야.
#     흥국화재2우B에 대한 회사 소개를 리포트로 만들어줘.
#     그리고 아래 정보들도 포함해서 리포트로 만들어줘.
#     등락률: 29.96
#     시가: 7600
#     고가: 9760
#     저가: 7350
#     종가: 9760
#     거래량: 20596
#     BPS: 0
#     PER: 0.0
#     PBR: 0.0
#     EPS: 0
#     DIV: 0.0
#     DPS: 0
#
#
#     오늘 KOSPI에서 26.77%로 상승으로 마감한 비상교육에 대한 정보야.
#     비상교육에 대한 회사 소개를 리포트로 만들어줘.
#     그리고 아래 정보들도 포함해서 리포트로 만들어줘.
#     등락률: 26.77
#     시가: 5400
#     고가: 6990
#     저가: 5340
#     종가: 6820
#     거래량: 7809842
#     BPS: 16097
#     PER: 0.0
#     PBR: 0.42
#     EPS: 0
#     DIV: 1.47
#     DPS: 100
#
#
#     오늘 KOSPI에서 21.5%로 상승으로 마감한 CR홀딩스에 대한 정보야.
#     CR홀딩스에 대한 회사 소개를 리포트로 만들어줘.
# ...
